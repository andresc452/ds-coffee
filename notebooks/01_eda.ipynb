# %% [markdown]
# # Exploratory Data Analysis (EDA) – Coffee Roasting ☕
#
# Objetivo:
#
# - Explorar el dataset de café para clasificar el nivel de tostado
# (**light** / **medium-light** / **medium** / **medium-dark** / **dark**) usando variables sensoriales y físicas.
#
# Este notebook NO entrena modelos.

# %% [markdown]
# # Import

# %%
# Standard Library
import os

# PySpark

# 1. Punto de Entrada principal a Spark
from pyspark.sql import SparkSession 

# 2.
from pyspark.sql.functions import col, sum as spark_num

# Spark ML (Estadistica)

# 1. Convierte multiples columnas numericas en un vector de Features
from pyspark.ml.feature import VectorAssembler 

# 2. Calc. de Correlación Distribuida en Spark
from pyspark.ml.stat import Correlation

# Data Manipulation for Plots
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Configuración Visual

# %%
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (6,4)

# %% [markdown]
# # SparkSession

# %%
spark = (
    SparkSession.builder
    .appName("Coffee-EDA")
    .getOrCreate()
)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/12/22 12:44:58 WARN Utils: Your hostname, COMADREJA-Air.local, resolves to a loopback address: 127.0.0.1; using 192.168.50.20 instead (on interface en0)
# 25/12/22 12:44:58 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/22 12:45:01 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# # Rutas al Dataset

# %%
DATA_PATH = os.path.join(
    "..","data","raw",""
)
# Out:
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# +---+
